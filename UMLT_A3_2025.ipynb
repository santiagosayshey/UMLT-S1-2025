# %% [markdown]
# # Assignment 3
# ## Sign Language Image Classification using Deep Learning

# %% [markdown]
# In this assignment you will implement different deep learning networks to classify images of hands in poses that correspond to letters in American Sign Language. The dataset is contained in the assignment zip file, along with some images and a text file describing the dataset. It is similar in many ways to other MNIST datasets.
#
# The American Sign Language letter database of hand gestures represent a multi-class problem with 24 classes of letters (**excluding J and Z which require motion**). The dataset format is patterned to match closely with the classic MNIST. Each training and test case represents a label (0-25) as a one-to-one map for each alphabetic letter A-Z (and **no cases for 9=J or 25=Z because of gesture motions**). The training data (27,455 cases) and test data (7172 cases) are approximately half the size of the standard MNIST but otherwise similar with a header row of label, $pixel_{1}$,$pixel_{2}$….$pixel_{784}$ which represent a single 28x28 pixel image with grayscale values between 0-255.
#
# ## Scenario
#
# A client is interested in having you (or rather the company that you work for) investigate whether it is possible to develop an app that would enable American sign language to be translated for people that do not sign, or those that sign in different languages/styles. They have provided you with a labelled data of images related to signs (hand positions) that represent individual letters in order to do a preliminary test of feasibility.
#
# Your manager has asked you to do this feasibility assessment, but subject to a constraint on the computational facilities available.  More specifically, you are asked to do **no more than 100 training runs in total** (including all models and hyperparameter settings that you consider).
#
# The task requires you to create a Jupyter Notebook to perform 22 steps. These steps involve loading the dataset, fixing data problems, converting labels to one-hot encoding, plotting sample images, creating, training, and evaluating two sequential models with 20 Dense layers with 100 neurons each, checking for better accuracy using MC Dropout, retraining the first model with performance scheduling, evaluating both models, using transfer learning to create a new model using pre-trained weights, freezing the weights of the pre-trained layers, adding new Dense layers, training and evaluating the new model, predicting and converting sign language to text using the best model.
#
# ### IMPORTANT
# * Train all the models locally on your own machine. No model training should occur on Gradescope (GS).
# * After completing the training, upload the trained models' **h5 files** and their training histories along with your notebook to GS.
#     * best_dnn_bn_model.keras
#     * best_dnn_bn_perf_model.keras
#     * best_dnn_selu_model.keras
#     * best_mobilenet_model.keras
#     * history1
#     * history2
#     * history1_perf
#     * historymb
# * To avoid any confusion and poor training on GS, please remember to comment out the training code in your notebook before uploading it to GS.

# %%
# import the necessary libraries (TensorFlow, sklearn NumPy, Pandas, Matplotlib and cv2)
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import os

print(tf.__version__)
print(keras.__version__)
# Out:
# 2.16.1
# 3.10.0

# %% [markdown]
# **Step0** This test is for checking whether all the required files are submitted. Once you submit all the required files to the autograder, you will be able to pass this step.
#
# **IMPORTANT:** Run this step to determine whether you have created all the required files correctly.
#
# _Points:_ 1

# %%
# Don't change this cell code
required_files = ['best_dnn_bn_model.keras','best_dnn_bn_perf_model.keras','best_dnn_selu_model.keras','best_mobilenet_model.keras','history1','history2','history1_perf','historymb']
step0_files = True
for file in required_files:
    if os.path.exists(file) == False:
        step0_files = False
        print("One or more files are missing!")
        break

# The following code is used by the autograder. Do not modify it.   
step0_data = step0_files
# Out:
# One or more files are missing!

# %%
grader.check("step00")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 grader.check("step00")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# **STEP1** Load the dataset (train and test) using `Pandas` from the CSV file.
#
# _Points:_ 1

# %%
# Load the train and test dataset and store them in train_df and test_df
train_df = pd.read_csv('sign_mnist_train.csv')
test_df = pd.read_csv('sign_mnist_test.csv')

# The following code is used by the autograder. Do not modify it.
step1_sol = test_df.shape

# %%
grader.check("step01")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 grader.check("step01")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **STEP2** Examine the data and fix any problems. Make sure it has 24 classes, starting from class 0. In addition, normalize the values of your images in a range of 0 and 1.
#
# _Points:_ 1

# %%
# Separate labels and pixel values in training and testing sets and assign it to train_labels and train_images
train_labels = train_df['label'].values
train_images = train_df.drop('label', axis=1).values

test_labels = test_df['label'].values
test_images = test_df.drop('label', axis=1).values

# Fix the mislabeled sample: change label 200 to 20 (U) (verified by looking at image, seemingly is U symbol)
train_labels[train_labels == 200] = 20

# Remap labels to be continuous 0-23
# Since J (9) and Z (25) don't exist, we shift all labels after 9 down by 1
# So: 0-8 stay same, 10→9, 11→10, ..., 24→23
train_labels = np.where(train_labels > 9, train_labels - 1, train_labels)
test_labels = np.where(test_labels > 9, test_labels - 1, test_labels)

# Normalize pixel values from 0-255 to 0-1 range
train_images = train_images / 255.0
test_images = test_images / 255.0

# The following code is used by the autograder. Do not modify it.
step2_sol = {
    "max_label_train": max(train_labels),
    "min_label_train": min(train_labels),
    "max_pixel_value_train": max(train_images.ravel()),
    "min_pixel_value_train": min(train_images.ravel()),
    "max_label_test": max(test_labels),
    "min_label_test": min(test_labels),
    "max_pixel_value_test": max(test_images.ravel()),
    "min_pixel_value_test": min(test_images.ravel())
}

# %%
grader.check("step02")

# %% [markdown]
# **STEP3** Convert Labels to One-Hot Encoding both train and test.
#
# _Points:_ 1

# %%
# One-hot encode the labels for 24 classes
train_labels_encoded = keras.utils.to_categorical(train_labels, num_classes=24)
test_labels_encoded = keras.utils.to_categorical(test_labels, num_classes=24)

# The following code is used by the autograder. Do not modify it.
step3_sol = {
    "train_labels_shape": train_labels_encoded.shape,
    "test_labels_shape": test_labels_encoded.shape,
    "sample_train_label": train_labels_encoded[0],
    "sample_test_label": test_labels_encoded[0]
}

# %%
grader.check("step03")

# %% [markdown]
# **STEP4** Plot one sample image for each letter in the dataset given in the training set. To solve this step you should use the function `imshow` to diplay your images in a similar to the image below.
#
# <center><img src="example_letters.jpg" width=400 height=300/></center>
#
#
#
#
#
# _Points:_ 0

# %%
# Get one sample image for each label
# Plot the sample images
images_to_plot = train_images.reshape(-1, 28, 28)

unique_labels_sorted = sorted(np.unique(train_labels))

fig, axes = plt.subplots(4, 6, figsize=(12, 9))
axes = axes.flatten()

for i, current_label_value in enumerate(unique_labels_sorted):
    if i < len(axes):
        idx = np.where(train_labels == current_label_value)[0][0]
        image_to_display = images_to_plot[idx]
        axes[i].imshow(image_to_display, cmap='gray')
        axes[i].set_title(f"Label {int(current_label_value)}") 
        axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
grader.check("step04")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 grader.check("step04")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# ## Create Neural Network Architectures
#
# In this part you should create two different models (model1 and model2) with different architectures.

# %% [markdown]
# **STEP5**
# Create one sequential model in `TensorFlow` with 20 Dense layers with 100 neurons each one. Consider the specific modifications that you need to do in order to work with your specific input and those to get the required output.
#
# * This model uses Batch Normalization after each Dense layer and uses He initialization for all of them. Apply Swish activation following each Batch Normalization.
# * The input layer should be able to accept data of shape (784,), which corresponds to the flattened image data. The output layer should produce 24 outputs to correspond to each class.
#
#
# _Points:_ 5

# %%
# import libraries like dense, BatchNormalization, swish, InputLayer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, InputLayer, Activation
from tensorflow.keras.activations import swish

model1 = Sequential()

# Input Layer
model1.add(InputLayer(input_shape=(784,)))

# 20 Hidden Layers
for _ in range(20):
    model1.add(Dense(100, kernel_initializer='he_normal'))
    model1.add(BatchNormalization())
    model1.add(Activation(swish))

# Output Layer
model1.add(Dense(24, activation='softmax'))

# Display the model's architecture
model1.summary()

# The following code is used by the autograder. Do not modify it.
step5_sol = {
    "total_layers": len(model1.layers),
    "output_activation": model1.layers[-1].activation.__name__,
    "first_layer_input_shape": model1.layers[0].input.shape,
    "last_layer_output_units": model1.layers[-1].units,
    "batch_norm_count": sum([1 for layer in model1.layers if isinstance(layer, BatchNormalization)]),
    "swish_activation_count": sum([1 for layer in model1.layers if hasattr(layer, 'activation') and (layer.activation == swish or (hasattr(layer.activation, '__name__') and layer.activation.__name__ == 'swish'))]),
}

# %%
grader.check("step05")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 grader.check("step05")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **STEP6**
# Create a second sequential model in `TensorFlow` . This model should incorporate specific features to promote self-normalization and include regularization:
#
# * Layers and Neurons: Construct the model with 20 Dense layers, each containing 100 neurons.
# * Activation and Initialization:
#   * Use SELU (Scaled Exponential Linear Unit) activation for each Dense layer to ensure self-normalization.
#   * Initialize weights using the LeCun normal initializer in all Dense layers.
# * Regularization:
#   * Integrate Dropout with a rate of 0.1 after every second Dense layer starting from the second Dense layer to enhance model regularization without breaking self-normalization.
# * Input and Output:
#   * The input layer should accept flattened images with a dimension of 784 (28x28 images flattened).
#   * The output layer should consist of 24 neurons with softmax activation to handle multi-class classification.
#
# _Points:_ 5

# %%
# Model 2: with SELU and self-normalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Dropout

model2 = Sequential()

# Input Layer
model2.add(InputLayer(input_shape=(784,))) # Or shape=(784,)

# 20 Hidden Layers
for i in range(1, 21):  # Loop from 1 to 20 for layer numbering
    model2.add(Dense(100, activation='selu', kernel_initializer='lecun_normal'))
    # Integrate Dropout after every second Dense layer (i.e., after layer 2, 4, ..., 20)
    if i % 2 == 0:
        model2.add(Dropout(0.1))

# Output Layer
model2.add(Dense(24, activation='softmax'))

# Display the model's architecture
model2.summary()

# The following code is used by the autograder. Do not modify it.
step6_sol = {
    "total_layers": len(model2.layers),
    "dropout_count": sum([1 for layer in model2.layers if isinstance(layer, Dropout)]),
    "selu_count": sum([1 for layer in model2.layers if hasattr(layer, 'activation') and hasattr(layer.activation, '__name__') and layer.activation.__name__ == 'selu']),
    "first_layer_config": model2.layers[0].get_config(), # Assuming InputLayer is layer 0
    "output_layer_activation": model2.layers[-1].activation.__name__
}
# Out:
# /home/sam-chau/ml_env/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_85 (Dense)                │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_86 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_89 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_90 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_91 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_92 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_93 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_96 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_97 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_26 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_99 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_100 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_101 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_102 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_103 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_104 (Dense)               │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_105 (Dense)               │ (None, 24)             │         2,424 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 272,824 (1.04 MB)
#  Trainable params: 272,824 (1.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
grader.check("step06")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 grader.check("step06")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# ## Compile the Models

# %% [markdown]
# **STEP7**
# Compile the both previous models using **Nadam** optimization. Also:
#
# * Set the loss function to categorical cross-entropy.
# * Set the metric to accuracy.
#
# _Points:_ 2

# %%
# Compile both models
model1.compile(optimizer='nadam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

model2.compile(optimizer='nadam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# The following code is used by the autograder. Do not modify it.
step7_sol = {
    "model1_config": {
        "optimizer": str(model1.optimizer.__class__.__name__),
        "loss": model1.loss
    },
    "model2_config": {
        "optimizer": str(model2.optimizer.__class__.__name__),
        "loss": model2.loss,
    }
}

# %%
grader.check("step07")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 grader.check("step07")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# ## Model Training

# %% [markdown]
# **STEP8** One of these models work preferably with data, which follow a normal distribution. Generate **train_images_scaled** and **test_images_scaled** using a `Sklearn` function that allow you to convert data to a normal distribution with mean 0 and variance equal 1 and store it in train_images_scaled and test_images_scaled
#
# _Points:_ 2

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training images and transform them
train_images_scaled = scaler.fit_transform(train_images)

# Transform the test images using the SAME scaler fitted on the training data
test_images_scaled = scaler.transform(test_images)

# The following code is used by the autograder. Do not modify it.
step8_sol = (np.mean(train_images_scaled),np.mean(test_images_scaled),np.std(train_images_scaled),np.std(test_images_scaled))

# %%
grader.check("step08")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 grader.check("step08")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **STEP9** Train the two models on the training dataset using early stopping. In order to save the results given by your training for your models, create checkpoints saving the best model in each case using the function `ModelCheckpoint`. Note that one of the models use the scaled data obtained in **STEP8**. Meanwhile, the other model does not. Figure out which is the proper input data for each model.
#
# * Limit the number of epochs to 100. Set the batch size to or greater than 32.
#
# **IMPORTANT:** Comment out the code to train/fit the two models. Keep the code given to save the models.
#
# _Points:_ 3

# %%
import pickle
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# The following line of code is used by the autograder. Do not modify it.
history1, history2 = None, None

# We go to set a seed to get the same results every run
np.random.seed(42)
tf.random.set_seed(42)

# Set up early stopping
early_stopping = EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss')

# Define model checkpoint callback
model1_checkpoint_cb = ModelCheckpoint("best_dnn_bn_model.keras", save_best_only=True, monitor='val_loss')
model2_checkpoint_cb = ModelCheckpoint("best_dnn_selu_model.keras", save_best_only=True, monitor='val_loss')

####################################
# Perform the training on your machine and then comment out the following section before uploading it to gradescope.
# Make sure your best model is named as follows:
# Model1 filename = best_dnn_bn_model.keras
# Model2 filename = best_dnn_selu_model.keras

# Define training parameters
epochs = 100
batch_size = 32

# Train model 1 (Comment this out before submission)
# history1 = model1.fit(train_images, train_labels_encoded,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.1,
#                       callbacks=[early_stopping, model1_checkpoint_cb])

# Train model 2 (Comment this out before submission)
# history2 = model2.fit(train_images_scaled, train_labels_encoded,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.1,
#                       callbacks=[early_stopping, model2_checkpoint_cb])

#####################################

# The following code will save your history - don't change it.
# if 'history1' in globals() and history1 is not None:
#     with open('./history1', 'wb') as file_pi:
#         pickle.dump(history1.history, file_pi)
# if 'history2' in globals() and history2 is not None:
#     with open('./history2', 'wb') as file_pi:
#         pickle.dump(history2.history, file_pi)
#####################################

# The following code is used by the autograder. Do not modify it.
step9_sol = (model1_checkpoint_cb, model2_checkpoint_cb, early_stopping)

# %%
grader.check("step09")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 grader.check("step09")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **STEP10** After training, you must now evaluate the performance of the two previously saved models using the test datasets. Each model has different data requirements:
# * Model 1 should be evaluated using the original test dataset.
# * Model 2 should be evaluated using the scaled test dataset.
# Load each model from their saved states, then perform the evaluation. To pass this step, both models must achieve a test accuracy greater than 50%.
#
# _Points:_ 2

# %%
# Do not change the following 4 lines of code.
# define the file name for the saved model
model1_name = "best_dnn_bn_model.keras"
# load the model
model1 = keras.models.load_model(model1_name)
# define the file name for the saved model
model2_name = "best_dnn_selu_model.keras"
# load the model
model2 = keras.models.load_model(model2_name)

# Evaluate the models on the test set
test_loss1, test_acc1 = model1.evaluate(test_images, test_labels_encoded)
test_loss2, test_acc2 = model2.evaluate(test_images_scaled, test_labels_encoded)
print(f"Model 1| Test accuracy: {test_acc1:.4f}, Test loss: {test_loss1:.4f}")
print(f"Model 2| Test accuracy: {test_acc2:.4f}, Test loss: {test_loss2:.4f}")

# The following code is used by the autograder. Do not modify it.
step10_sol = (test_loss1, test_acc1, test_loss2, test_acc2, model1, model2)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7058 - loss: 1.5938
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7832 - loss: 1.4294
# Model 1| Test accuracy: 0.7105, Test loss: 1.5581
# Model 2| Test accuracy: 0.7861, Test loss: 1.4285

# %%
grader.check("step10")

# %% [markdown]
# **STEP11** From the loaded history of the two trained models, plot a graph of **accuracy** vs **number of epochs** for both training and validation.
#
# _Points:_ 0

# %%
# Load history for model 1 (Do not modify this code)
history_name1 = "./history1"
with open(history_name1, "rb") as file_pi:
    loaded_history1 = pickle.load(file_pi)
    
# Load history for model 2 (Do not modify this code)
history_name2 = "./history2"
with open(history_name2, "rb") as file_pi:
    loaded_history2 = pickle.load(file_pi)

# Plot the training and validation accuracies during training for both models
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Model 1 plot
ax1.plot(loaded_history1['accuracy'], label='Training Accuracy')
ax1.plot(loaded_history1['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Model 1 (BatchNorm) - Accuracy vs Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Model 2 plot
ax2.plot(loaded_history2['accuracy'], label='Training Accuracy')
ax2.plot(loaded_history2['val_accuracy'], label='Validation Accuracy')
ax2.set_title('Model 2 (SELU) - Accuracy vs Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# The following code is used by the autograder. Do not modify it.
step11_sol = (loaded_history1, loaded_history2)

# %%
grader.check("step11")

# %% [markdown]
# ## MC Dropout

# %% [markdown]
# **STEP12** Check if model2 achieves better accuracy using MC Dropout (without retraining).
#
# _Points:_ 3

# %%
#This function computes the MC (Monte Carlo) Dropout predictions for a given model and input data. 
# It returns the mean of multiple predictions obtained by running the model in training mode.
#Parameters
#   model: A trained model with a dropout layers.
#   X    : The input data for which the predictions are to be made.
#   n_samples: The number of Monte Carlo samples to generate..
#Returns
  # The function returns an array-like object containing the MC Dropout predictions for the given input data. 
  # The shape of the output should be the same as the model's output layer.
def mc_dropout_predict(model, X, n_samples=20):
    predictions = []
    
    # Run n_samples predictions with dropout active
    for _ in range(n_samples):
        # Model in training mode keeps dropout active
        preds = model(X, training=True)
        predictions.append(preds)
    
    # Average the predictions
    output_mc = np.mean(predictions, axis=0)
    return output_mc

# call mc_dropout_predict to Compute the MC Dropout predictions for model 2
output_mc = mc_dropout_predict(model2, test_images_scaled, n_samples=20)

# Compute the accuracy using MC Dropout
predicted_classes = np.argmax(output_mc, axis=1)
true_classes = np.argmax(test_labels_encoded, axis=1)
accuracy_mc = np.mean(predicted_classes == true_classes)

# Display result.
print(f"Model 2 with MC Dropout: Test accuracy: {accuracy_mc:.4f}")

# The following code is used by the autograder. Do not modify it.
step12_sol = (output_mc, accuracy_mc)
# Out:
# Model 2 with MC Dropout: Test accuracy: 0.7863

# %%
grader.check("step12")

# %% [markdown]
# ## Learning Rate (LR) scheduling

# %% [markdown]
# **STEP13** Retrain model1 using performance scheduling and see if it improves training speed and model accuracy.
#
# **IMPORTANT:** Define the model the same way model1 was defined and compile the model the same way as model1.
#
# _Points:_ 2

# %%
# import ReduceLROnPlateau
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Do not modify the following line of code.
history1_perf = None

# Redefine Model 1 
model1_perfLRS = Sequential()

# Input Layer
model1_perfLRS.add(InputLayer(input_shape=(784,)))

# 20 Hidden Layers - same as original model1
for _ in range(20):
    model1_perfLRS.add(Dense(100, kernel_initializer='he_normal'))
    model1_perfLRS.add(BatchNormalization())
    model1_perfLRS.add(Activation(swish))

# Output Layer
model1_perfLRS.add(Dense(24, activation='softmax'))

early_stopping_cb = EarlyStopping(patience=10, restore_best_weights=True, monitor='val_loss')

# Compile the model with Nadam optimizer and categorical cross-entropy loss
model1_perfLRS.compile(optimizer='nadam',
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', 
                                 factor=0.5,           # Reduce LR by half
                                 patience=5,           # Wait 5 epochs before reducing
                                 min_lr=1e-7,          # Minimum learning rate
                                 verbose=1)            # Print when LR is reduced

# Creating model checkpoint to save the best model. 
dnn_bn_perf_checkpoint_cb = ModelCheckpoint("best_dnn_bn_perf_model.keras", 
                                           save_best_only=True, 
                                           monitor='val_loss')

#####Perform the training on your machine and then comment out the following section before uploading it to gradescope.
####################################  
# Make sure your best model is named as follows:
# Model1 with performance scheduling filename = best_dnn_bn_perf_model.keras

# Train the model using early stopping and exponential scheduling (Comment this out before submission)
# history1_perf = model1_perfLRS.fit(train_images, train_labels_encoded,
#                                    epochs=100,
#                                    batch_size=32,
#                                    validation_split=0.1,
#                                    callbacks=[early_stopping_cb, lr_scheduler, dnn_bn_perf_checkpoint_cb])

# The following code will save your history - don't change it - comment it out before uploading to GS
# if "history1_perf" in globals():
#     with open('./history1_perf', 'wb') as file_pi:
#         pickle.dump(history1_perf.history, file_pi)
####################################
# The following code is used by the autograder. Do not modify it.
step13_sol = (dnn_bn_perf_checkpoint_cb, lr_scheduler)
# Out:
# /home/sam-chau/ml_env/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/100
# 2025-05-30 16:12:29.381439: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 77487424 exceeds 10% of free system memory.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - accuracy: 0.1896 - loss: 2.7096 - val_accuracy: 0.1857 - val_loss: 3.7295 - learning_rate: 0.0010
# Epoch 2/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6554 - loss: 1.0561 - val_accuracy: 0.3216 - val_loss: 2.9884 - learning_rate: 0.0010
# Epoch 3/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8248 - loss: 0.5497 - val_accuracy: 0.3376 - val_loss: 2.9269 - learning_rate: 0.0010
# Epoch 4/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8927 - loss: 0.3422 - val_accuracy: 0.4971 - val_loss: 2.0665 - learning_rate: 0.0010
# Epoch 5/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9116 - loss: 0.2915 - val_accuracy: 0.4519 - val_loss: 2.5333 - learning_rate: 0.0010
# Epoch 6/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9343 - loss: 0.2173 - val_accuracy: 0.4002 - val_loss: 3.4209 - learning_rate: 0.0010
# Epoch 7/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9510 - loss: 0.1619 - val_accuracy: 0.6854 - val_loss: 1.2231 - learning_rate: 0.0010
# Epoch 8/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9574 - loss: 0.1398 - val_accuracy: 0.4450 - val_loss: 2.8773 - learning_rate: 0.0010
# Epoch 9/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9645 - loss: 0.1205 - val_accuracy: 0.5725 - val_loss: 1.9352 - learning_rate: 0.0010
# Epoch 10/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9672 - loss: 0.1175 - val_accuracy: 0.7684 - val_loss: 0.8208 - learning_rate: 0.0010
# Epoch 11/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9733 - loss: 0.0899 - val_accuracy: 0.6082 - val_loss: 1.8654 - learning_rate: 0.0010
# Epoch 12/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9624 - loss: 0.1349 - val_accuracy: 0.6213 - val_loss: 1.9391 - learning_rate: 0.0010
# Epoch 13/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9792 - loss: 0.0672 - val_accuracy: 0.6646 - val_loss: 1.3402 - learning_rate: 0.0010
# Epoch 14/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9779 - loss: 0.0765 - val_accuracy: 0.3973 - val_loss: 4.7238 - learning_rate: 0.0010
# Epoch 15/100
# 766/773 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9691 - loss: 0.1037
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9691 - loss: 0.1035 - val_accuracy: 0.6366 - val_loss: 1.9144 - learning_rate: 0.0010
# Epoch 16/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9934 - loss: 0.0229 - val_accuracy: 0.9931 - val_loss: 0.0242 - learning_rate: 5.0000e-04
# Epoch 17/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 1.1314e-04 - learning_rate: 5.0000e-04
# Epoch 18/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 2.6247e-05 - learning_rate: 5.0000e-04
# Epoch 19/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 1.0000 - loss: 5.1712e-04 - val_accuracy: 1.0000 - val_loss: 9.7063e-05 - learning_rate: 5.0000e-04
# Epoch 20/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.5986e-04 - val_accuracy: 1.0000 - val_loss: 7.3605e-06 - learning_rate: 5.0000e-04
# Epoch 21/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.7353e-04 - val_accuracy: 1.0000 - val_loss: 4.9615e-06 - learning_rate: 5.0000e-04
# Epoch 22/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.2279e-04 - val_accuracy: 1.0000 - val_loss: 3.3669e-06 - learning_rate: 5.0000e-04
# Epoch 23/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 8.7374e-05 - val_accuracy: 1.0000 - val_loss: 2.2602e-06 - learning_rate: 5.0000e-04
# Epoch 24/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 6.1842e-05 - val_accuracy: 1.0000 - val_loss: 1.4904e-06 - learning_rate: 5.0000e-04
# Epoch 25/100
# 772/773 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.3350e-05
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 4.3349e-05 - val_accuracy: 1.0000 - val_loss: 9.6101e-07 - learning_rate: 5.0000e-04
# Epoch 26/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 3.0760e-05 - val_accuracy: 1.0000 - val_loss: 7.2324e-07 - learning_rate: 2.5000e-04
# Epoch 27/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.4920e-05 - val_accuracy: 1.0000 - val_loss: 5.4378e-07 - learning_rate: 2.5000e-04
# Epoch 28/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 1.0000 - loss: 1.9618e-05 - val_accuracy: 1.0000 - val_loss: 3.8602e-07 - learning_rate: 2.5000e-04
# Epoch 29/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 1.0000 - loss: 1.4903e-05 - val_accuracy: 1.0000 - val_loss: 2.5882e-07 - learning_rate: 2.5000e-04
# Epoch 30/100
# 770/773 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0957e-05
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.0957e-05 - val_accuracy: 1.0000 - val_loss: 1.6115e-07 - learning_rate: 2.5000e-04
# Epoch 31/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 8.0002e-06 - val_accuracy: 1.0000 - val_loss: 1.1626e-07 - learning_rate: 1.2500e-04
# Epoch 32/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 6.5712e-06 - val_accuracy: 1.0000 - val_loss: 8.0659e-08 - learning_rate: 1.2500e-04
# Epoch 33/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 5.2310e-06 - val_accuracy: 1.0000 - val_loss: 5.1183e-08 - learning_rate: 1.2500e-04
# Epoch 34/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 4.0164e-06 - val_accuracy: 1.0000 - val_loss: 3.1040e-08 - learning_rate: 1.2500e-04
# Epoch 35/100
# 771/773 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9903e-06
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.9903e-06 - val_accuracy: 1.0000 - val_loss: 1.7799e-08 - learning_rate: 1.2500e-04
# Epoch 36/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.2126e-06 - val_accuracy: 1.0000 - val_loss: 1.2242e-08 - learning_rate: 6.2500e-05
# Epoch 37/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.8387e-06 - val_accuracy: 1.0000 - val_loss: 8.1615e-09 - learning_rate: 6.2500e-05
# Epoch 38/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.4891e-06 - val_accuracy: 1.0000 - val_loss: 4.8621e-09 - learning_rate: 6.2500e-05
# Epoch 39/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.1762e-06 - val_accuracy: 1.0000 - val_loss: 2.9086e-09 - learning_rate: 6.2500e-05
# Epoch 40/100
# 767/773 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.1025e-07
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 9.1031e-07 - val_accuracy: 1.0000 - val_loss: 1.6497e-09 - learning_rate: 6.2500e-05
# Epoch 41/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 7.0757e-07 - val_accuracy: 1.0000 - val_loss: 1.1287e-09 - learning_rate: 3.1250e-05
# Epoch 42/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 6.1046e-07 - val_accuracy: 1.0000 - val_loss: 7.8142e-10 - learning_rate: 3.1250e-05
# Epoch 43/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 5.2282e-07 - val_accuracy: 1.0000 - val_loss: 5.6436e-10 - learning_rate: 3.1250e-05
# Epoch 44/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 4.4423e-07 - val_accuracy: 1.0000 - val_loss: 3.9071e-10 - learning_rate: 3.1250e-05
# Epoch 45/100
# 770/773 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.7750e-07
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 3.7755e-07 - val_accuracy: 1.0000 - val_loss: 8.6824e-11 - learning_rate: 3.1250e-05
# Epoch 46/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 3.2361e-07 - val_accuracy: 1.0000 - val_loss: 4.3412e-11 - learning_rate: 1.5625e-05
# Epoch 47/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.9726e-07 - val_accuracy: 1.0000 - val_loss: 4.3412e-11 - learning_rate: 1.5625e-05
# Epoch 48/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 1.0000 - loss: 2.7348e-07 - val_accuracy: 1.0000 - val_loss: 4.3412e-11 - learning_rate: 1.5625e-05
# Epoch 49/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.5234e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.5625e-05
# Epoch 50/100
# 766/773 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.3317e-07
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.3328e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 1.5625e-05
# Epoch 51/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.1717e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.8125e-06
# Epoch 52/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.0898e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.8125e-06
# Epoch 53/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 2.0089e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.8125e-06
# Epoch 54/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.9400e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.8125e-06
# Epoch 55/100
# 767/773 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.8722e-07
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.8731e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 7.8125e-06
# Epoch 56/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.8147e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.9063e-06
# Epoch 57/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.7835e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.9063e-06
# Epoch 58/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.7537e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.9063e-06
# Epoch 59/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 1.0000 - loss: 1.7245e-07 - val_accuracy: 1.0000 - val_loss: 0.0000e+00 - learning_rate: 3.9063e-06

# %%
grader.check("step13")

# %% [markdown]
# **STEP14** Using the loaded model obtained from the code given below, evaluate the performance of the model on the test set.
#
# _Points:_ 1

# %%
# Do not change the following 2 lines of code.
# define the file name for the saved model
model_name = "best_dnn_bn_perf_model.keras"
# load the model
model1_perf = keras.models.load_model(model_name)

# Evaluate the model on the test set and find loss and accuracy
test_loss1_perf, test_acc1_perf = model1_perf.evaluate(test_images, test_labels_encoded)

# The following code is used by the autograder. Do not modify it.
step14_sol = (test_loss1_perf, test_acc1_perf)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8350 - loss: 1.8414

# %%
grader.check("step14")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 grader.check("step14")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **STEP15** From the history of the models loaded using the code given below, plot a graph of **accuracy** vs **number of epochs** for both training and validation.
#
# _Points:_ 0

# %%
# load history for model 1 with learning rate scheduling (do not modify the following code)
history_name1_perf = "./history1_perf"
with open(history_name1_perf, "rb") as file_pi:
    loaded_history1_perf = pickle.load(file_pi)

# Load history for the original model1 (do not modify the following code)
history_name1 = "./history1"
with open(history_name1, "rb") as file_pi:
    loaded_history1 = pickle.load(file_pi)

# Plot the training and validation accuracy for both models
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Original Model 1 plot
ax1.plot(loaded_history1['accuracy'], label='Training Accuracy')
ax1.plot(loaded_history1['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Original Model 1 (BatchNorm) - Accuracy vs Epochs')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Model 1 with LR Scheduling plot
ax2.plot(loaded_history1_perf['accuracy'], label='Training Accuracy')
ax2.plot(loaded_history1_perf['val_accuracy'], label='Validation Accuracy')
ax2.set_title('Model 1 with LR Scheduling - Accuracy vs Epochs')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
grader.check("step15")

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Transfer learning
#
# Use transfer learning by using a pre-trained **MobileNetV3Small** model on imagenet dataset, and fine-tuning it on the Sign Language MNIST dataset.

# %% [markdown]
# **STEP16** First of all, you to prepare your data for this model.
# * Reshape your input data (train and test) to (28, 28, 3).
# * Standardize your input.
#
# _Points:_ 2

# %%
# First reshape the flattened images to 28x28x1
train_images_reshaped = train_images.reshape(-1, 28, 28, 1)
test_images_reshaped = test_images.reshape(-1, 28, 28, 1)

# Convert grayscale to RGB by repeating the channel 3 times
train_images_rgb = np.repeat(train_images_reshaped, 3, axis=3)
test_images_rgb = np.repeat(test_images_reshaped, 3, axis=3)

# Standardize the input using StandardScaler
# We need to reshape for StandardScaler (it expects 2D input)
train_images_flat = train_images_rgb.reshape(-1, 28*28*3)
test_images_flat = test_images_rgb.reshape(-1, 28*28*3)

# Standardize
scaler_mb = StandardScaler()
train_images_standardized = scaler_mb.fit_transform(train_images_flat)
test_images_standardized = scaler_mb.transform(test_images_flat)

# Reshape back to image format
train_images_mb = train_images_standardized.reshape(-1, 28, 28, 3)
test_images_mb = test_images_standardized.reshape(-1, 28, 28, 3)

# The following code is used by the autograder. Do not modify it.
step16_sol = (train_images_mb,test_images_mb)

# %%
grader.check("step16")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 grader.check("step16")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **Step17** Now, we need to define and set up the model. For this you need to follow the next steps:
#
# * Load the pre-trained **MobileNetV3Small** model with weights from ImageNet.
# * Modify the model to accept inputs of shape (56, 56, 3).
# * Freeze the weights of the pretrained layers.*
# * Add input layer that take an image of shape (28,28,3), then a layer `UpSampling2D` to upscale the input by a factor of 2 so they can go through the network.
#
# Consider that maybe you need to adapt the default output.
#
# _Points:_ 2

# %%
# import MobileNetV3Small 
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Input, UpSampling2D, Dense
from tensorflow.keras.models import Model

# Load the pre-trained MobileNet model with weights from ImageNet
base_mb_model = MobileNetV3Small(weights='imagenet', 
                                 include_top=False, 
                                 input_shape=(56, 56, 3),
                                 pooling='avg')

# Freeze the weights of pretrained layers
base_mb_model.trainable = False

# Create the new model
inputs = Input(shape=(28, 28, 3))
x = UpSampling2D(size=(2, 2))(inputs)  # Upscale from 28x28 to 56x56
x = base_mb_model(x)
outputs = Dense(24, activation='softmax')(x)

final_mb_model = Model(inputs=inputs, outputs=outputs)

# The following code is used by the autograder. Do not modify it.
step17_sol = final_mb_model
# Out:
# /home/sam-chau/ml_env/lib/python3.12/site-packages/keras/src/applications/mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
grader.check("step17")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 grader.check("step17")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **Step18** Once we define the model and do the specific modifications to adjust to our data, we compile it.
#
# * Use a learning rate schedule that uses an exponential decay schedule.
# * Compile and train the model.
#
# _Points:_ 2

# %%
# Define an initial learning rate                            
initial_learning_rate = 0.001

# Create the proper learning rate schedule
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100,
    decay_rate=0.96,
    staircase=True)

# Compile model
final_mb_model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

# The following code is used by the autograder. Do not modify it.
step18_sol = (lr_schedule, final_mb_model)

# %%
grader.check("step18")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 grader.check("step18")
#
# NameError: name 'grader' is not defined

# %% [markdown]
# **Step19** Train the mobilenet model. Include early stopping in your training procedure.
#
# _Points:_ 2

# %%
# import ModelCheckpoint
from tensorflow.keras.callbacks import ModelCheckpoint
# Do not modify the following line of code.
history_mb = None
# Define model checkpoint callback (Do not modify this code).
best_model_checkpoint = ModelCheckpoint("best_mobilenet_model.keras", 
                                       save_best_only=True, 
                                       monitor='val_loss')

# Set up early stopping
early_stopping_cb = EarlyStopping(patience=10, 
                                 restore_best_weights=True, 
                                 monitor='val_loss')

## Perform the training on your machine and then comment out the following section before uploading it to gradescope. 
#################################### 
# make sure your best model is named as follow:
# MobileNet model filename = best_mobilenet_model.keras
# Train the model (comment this section out)
history_mb = final_mb_model.fit(train_images_mb, train_labels_encoded,
                               epochs=100,
                               batch_size=32,
                               validation_split=0.1,
                               callbacks=[early_stopping_cb, best_model_checkpoint])

# The following code will save your history - don't change it
if "history_mb" in globals():
    with open('./historymb', 'wb') as file_pi:
        pickle.dump(history_mb.history, file_pi)    
####################################

# The following code is used by the autograder. Do not modify it.
step19_sol = (best_model_checkpoint, early_stopping_cb)
# Out:
# Epoch 1/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.1459 - loss: 3.0149 - val_accuracy: 0.3372 - val_loss: 2.5675
# Epoch 2/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.3849 - loss: 2.5021 - val_accuracy: 0.4348 - val_loss: 2.3049
# Epoch 3/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.4698 - loss: 2.2767 - val_accuracy: 0.4920 - val_loss: 2.1604
# Epoch 4/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5121 - loss: 2.1483 - val_accuracy: 0.5353 - val_loss: 2.0709
# Epoch 5/100
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5393 - loss: 2.0672 - val_accuracy: 0.5590 - val_loss: 2.0120
# Epoch 6/100
# 213/773 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.5577 - loss: 2.0170

# %%
grader.check("step19")

# %% [markdown]
# **Step20** For the trained model loaded using the code given below, evaluate its performance on the test set.
#
# _Points:_ 1

# %%
# Do not modify the following two lines of code.
# define the file name for the saved model
model_name = "best_mobilenet_model.keras"
# load the model
final_mb_model = keras.models.load_model(model_name)

# Reshape the input data to (num_samples, 28, 28, 3)

# Evaluate the model on the test set
test_loss1_mobilenet, test_acc1_mobilenet = ...
print(f"Model Mobile Net: Test accuracy: {test_acc1_mobilenet:.4f}")

# The following code is used by the autograder. Do not modify it.
step20_sol = (test_loss1_mobilenet,test_acc1_mobilenet)

# %%
grader.check("step20")

# %% [markdown]
# **Step21** So far, you have seen the overall performance of your models. However, it is possible that some classes may be more difficult to classify than others. To gain a clearer understanding of which letters are the most difficult or easiest to predict, you can use your MobileNet model and make predictions on your test data using the predict function. Based on this, you can check the proportion of correct matches for each letter over the total number of that specific letter in the test data (as the proportion of one letter may differ from that of others). Finally, return the result as a string indicating the most complex and easiest letter to predict based on our analysis (e.g., "a" in lowercase).
#
# _Points:_ 2

# %%
# Put here again the labels (not hot encoded)

# Make the prediction using MobileNet model. Use the function predict.

# What is the most difficult letter to predict? (if you have many letters which are equally difficult to predict, pick up any of them. Only one and put in a string (e.g. "a"))

# What is the easist letter to predict? (if you have many letters which are equally easy to predict, pick up any of them. Only one and put in a string (e.g. "a"))

# The following code is used by the autograder. Do not modify it.
step21_sol = (test_labels,prediction_test,complex_letter,easiest_letter)

# %%
grader.check("step21")

# %% [markdown]
# ## Using our final model

# %% [markdown]
# **Step22**
#
# **Predict on a new sample** Process the image `challenge1.jpg` and try to dechiper what is the letter in the image using your best model. Be aware that your model gives you numeric results, however you should convert this result in a proper output of letters (use lowercase letters).
#
# _Points:_ 2

# %%
# Load the image (do not modify this line of code)
img_challenge1 = cv2.imread('challenge1.jpg', cv2.IMREAD_GRAYSCALE)

# Plot the image (do not modify the following 2 lines of code)
plt.imshow(img_challenge1)
plt.show()

# Process the data

# Predict in this data using your best model
prediction_challenge1 = ...


# Decoding result. This should be the string representation of the output generated by your model.
result_challenge1 = ...

# The following code is used by the autograder. Do not modify it.
step22_sol = (result_challenge1)

# %%
grader.check("step22")
